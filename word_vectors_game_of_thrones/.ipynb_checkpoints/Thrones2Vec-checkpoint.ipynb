# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sajid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sajid\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data\\got1.txt',
#  'data\\got2.txt',
#  'data\\got3.txt',
#  'data\\got4.txt',
#  'data\\got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data\got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data\got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data\got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data\got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data\got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[11])
print(sentence_to_wordlist(raw_sentences[11]))
# Out:
# Their droppings speckled the gargoyles that rose twelve feet tall on either side of him, a hellhound and a wyvern, two of the thousand that brooded over the walls of the ancient fortress.
# ['Their', 'droppings', 'speckled', 'the', 'gargoyles', 'that', 'rose', 'twelve', 'feet', 'tall', 'on', 'either', 'side', 'of', 'him', 'a', 'hellhound', 'and', 'a', 'wyvern', 'two', 'of', 'the', 'thousand', 'that', 'brooded', 'over', 'the', 'walls', 'of', 'the', 'ancient', 'fortress']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized

num_features = 3000
# Minimum word count threshold.
min_word_count = 11

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 10

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-5

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 5

# %%
thrones2vec = w2v.Word2Vec(
    sg=10,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2019-06-29 02:35:04,321 : INFO : collecting all words and their counts
# 2019-06-29 02:35:04,322 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-06-29 02:35:04,343 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2019-06-29 02:35:04,366 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2019-06-29 02:35:04,389 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2019-06-29 02:35:04,411 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2019-06-29 02:35:04,432 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2019-06-29 02:35:04,455 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2019-06-29 02:35:04,478 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2019-06-29 02:35:04,501 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2019-06-29 02:35:04,526 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2019-06-29 02:35:04,547 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2019-06-29 02:35:04,569 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2019-06-29 02:35:04,593 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2019-06-29 02:35:04,614 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2019-06-29 02:35:04,614 : INFO : Loading a fresh vocabulary
# 2019-06-29 02:35:04,717 : INFO : effective_min_count=11 retains 8605 unique words (29% of original 29026, drops 20421)
# 2019-06-29 02:35:04,718 : INFO : effective_min_count=11 leaves 1756404 word corpus (96% of original 1818103, drops 61699)
# 2019-06-29 02:35:04,742 : INFO : deleting the raw counts dictionary of 29026 items
# 2019-06-29 02:35:04,743 : INFO : sample=1e-05 downsamples 3379 most-common words
# 2019-06-29 02:35:04,743 : INFO : downsampling leaves estimated 391632 word corpus (22.3% of prior 1756404)
# 2019-06-29 02:35:04,764 : INFO : estimated required memory for 8605 words and 3000 dimensions: 210822500 bytes
# 2019-06-29 02:35:04,764 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 8605

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, total_words=token_count, epochs=100)
# Out:
# 2019-06-29 02:35:07,930 : INFO : training model with 6 workers on 8605 vocabulary and 3000 features, using sg=10 hs=0 sample=1e-05 negative=5 window=10
# 2019-06-29 02:35:08,957 : INFO : EPOCH 1 - PROGRESS: at 20.31% words, 77809 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:09,961 : INFO : EPOCH 1 - PROGRESS: at 42.84% words, 82232 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:10,965 : INFO : EPOCH 1 - PROGRESS: at 64.81% words, 84244 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:11,998 : INFO : EPOCH 1 - PROGRESS: at 86.23% words, 83531 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:12,489 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:35:12,506 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:35:12,512 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:35:12,513 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:35:12,520 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:35:12,574 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:35:12,575 : INFO : EPOCH - 1 : training on 1818103 raw words (391304 effective words) took 4.6s, 84581 effective words/s
# 2019-06-29 02:35:13,603 : INFO : EPOCH 2 - PROGRESS: at 20.86% words, 80251 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:14,618 : INFO : EPOCH 2 - PROGRESS: at 43.93% words, 84020 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:15,685 : INFO : EPOCH 2 - PROGRESS: at 65.36% words, 82982 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:16,688 : INFO : EPOCH 2 - PROGRESS: at 87.33% words, 83658 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:17,128 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:35:17,133 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:35:17,138 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:35:17,161 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:35:17,176 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:35:17,223 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:35:17,224 : INFO : EPOCH - 2 : training on 1818103 raw words (391693 effective words) took 4.6s, 84535 effective words/s
# 2019-06-29 02:35:18,295 : INFO : EPOCH 3 - PROGRESS: at 21.41% words, 78741 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:19,348 : INFO : EPOCH 3 - PROGRESS: at 44.48% words, 81771 words/s, in_qsize 12, out_qsize 0
# 2019-06-29 02:35:20,413 : INFO : EPOCH 3 - PROGRESS: at 65.36% words, 80837 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:21,416 : INFO : EPOCH 3 - PROGRESS: at 87.33% words, 81992 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:35:21,869 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:35:21,876 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:35:21,885 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:35:21,904 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:35:21,908 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:35:21,941 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:35
: INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:42:25,712 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:42:25,720 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:42:25,736 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:42:25,744 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:42:25,775 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:42:25,776 : INFO : EPOCH - 98 : training on 1818103 raw words (390841 effective words) took 4.1s, 94771 effective words/s
# 2019-06-29 02:42:26,799 : INFO : EPOCH 99 - PROGRESS: at 23.06% words, 88676 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:27,801 : INFO : EPOCH 99 - PROGRESS: at 47.23% words, 91331 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:28,811 : INFO : EPOCH 99 - PROGRESS: at 71.39% words, 92882 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:29,813 : INFO : EPOCH 99 - PROGRESS: at 95.55% words, 92992 words/s, in_qsize 9, out_qsize 0
# 2019-06-29 02:42:29,859 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:42:29,898 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:42:29,899 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:42:29,911 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:42:29,919 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:42:29,948 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:42:29,949 : INFO : EPOCH - 99 : training on 1818103 raw words (391397 effective words) took 4.2s, 94109 effective words/s
# 2019-06-29 02:42:30,989 : INFO : EPOCH 100 - PROGRESS: at 23.61% words, 89670 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:31,997 : INFO : EPOCH 100 - PROGRESS: at 48.33% words, 92771 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:33,021 : INFO : EPOCH 100 - PROGRESS: at 72.49% words, 93411 words/s, in_qsize 11, out_qsize 0
# 2019-06-29 02:42:34,053 : INFO : EPOCH 100 - PROGRESS: at 97.20% words, 93174 words/s, in_qsize 6, out_qsize 0
# 2019-06-29 02:42:34,057 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-06-29 02:42:34,074 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-06-29 02:42:34,083 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-06-29 02:42:34,088 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-29 02:42:34,097 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-29 02:42:34,128 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-29 02:42:34,128 : INFO : EPOCH - 100 : training on 1818103 raw words (391994 effective words) took 4.2s, 94149 effective words/s
# 2019-06-29 02:42:34,129 : INFO : training on a 181810300 raw words (39165717 effective words) took 446.2s, 87777 effective words/s
# (39165717, 181810300)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-06-29 02:42:58,915 : INFO : saving Word2Vec object under trained\thrones2vec.w2v, separately None
# 2019-06-29 02:42:58,916 : INFO : storing np array 'vectors' to trained\thrones2vec.w2v.wv.vectors.npy
# 2019-06-29 02:42:59,875 : INFO : not storing attribute vectors_norm
# 2019-06-29 02:42:59,876 : INFO : storing np array 'syn1neg' to trained\thrones2vec.w2v.trainables.syn1neg.npy
# 2019-06-29 02:43:00,827 : INFO : not storing attribute cum_table
# 2019-06-29 02:43:00,828 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-29 02:43:00,943 : INFO : saved trained\thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-06-29 02:43:12,348 : INFO : loading Word2Vec object from trained\thrones2vec.w2v
# 2019-06-29 02:43:12,349 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-29 02:43:12,365 : INFO : loading wv recursively from trained\thrones2vec.w2v.wv.* with mmap=None
# 2019-06-29 02:43:12,366 : INFO : loading vectors from trained\thrones2vec.w2v.wv.vectors.npy with mmap=None
# 2019-06-29 02:43:12,422 : INFO : setting ignored attribute vectors_norm to None
# 2019-06-29 02:43:12,423 : INFO : loading vocabulary recursively from trained\thrones2vec.w2v.vocabulary.* with mmap=None
# 2019-06-29 02:43:12,423 : INFO : loading trainables recursively from trained\thrones2vec.w2v.trainables.* with mmap=None
# 2019-06-29 02:43:12,424 : INFO : loading syn1neg from trained\thrones2vec.w2v.trainables.syn1neg.npy with mmap=None
# 2019-06-29 02:43:12,468 : INFO : setting ignored attribute cum_table to None
# 2019-06-29 02:43:12,468 : INFO : loaded trained\thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# F:\Anaconda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#        word          x         y
# 0      This   0.954392 -3.244866
# 1       the   2.700203 -3.244104
# 2  complete   9.945182 -7.257760
# 3        of   2.841787 -3.545082
# 4         A   2.983477 -3.654727
# 5        OF -16.593493  7.658426
# 6    Bantam -13.876546  9.513598
# 7   Spectra -13.946465  9.474974
# 8      Book -13.595413  9.571760
# 9       and   2.799478 -3.211957

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(1.0, 5.0), y_bounds=(-0.5, -0.1))

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(3, 4.5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.wv.most_similar("Sansa")
# Out:
# [('Joffrey', 0.3165239095687866),
#  ('Arya', 0.2592741847038269),
#  ('She', 0.2537185251712799),
#  ('Catelyn', 0.24248668551445007),
#  ('Mordane', 0.23836877942085266),
#  ('Brella', 0.23509356379508972),
#  ('Margaery', 0.2314138114452362),
#  ('Bran', 0.23029829561710358),
#  ('Cersei', 0.23020869493484497),
#  ('Sweetrobin', 0.22909505665302277)]

# %%
thrones2vec.wv.most_similar("Aerys")
# Out:
# [('II', 0.41242215037345886),
#  ('Mad', 0.31930702924728394),
#  ('Jaehaerys', 0.30387818813323975),
#  ('Rossart', 0.28726834058761597),
#  ('Targaryen', 0.2802354693412781),
#  ('Aerion', 0.2708052098751068),
#  ('Years', 0.2622000575065613),
#  ('Bells', 0.26167336106300354),
#  ('exiled', 0.2616727948188782),
#  ('Daeron', 0.2583908140659332)]

# %%
thrones2vec.wv.most_similar("direwolf")
# Out:
# [('SNOW', 0.30587610602378845),
#  ('BRANDON', 0.2868254780769348),
#  ('bounding', 0.27843135595321655),
#  ('prowling', 0.27525442838668823),
#  ('presumed', 0.27137383818626404),
#  ('STARK', 0.268568217754364),
#  ('muzzle', 0.2683123052120209),
#  ('Ghost', 0.2658213973045349),
#  ('Shaggy', 0.25688979029655457),
#  ('protector', 0.25036460161209106)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Targaryen")
nearest_similarity_cosmul("Jaime", "Kingslayer", "Tywin")
nearest_similarity_cosmul("Dany", "Queen", "Jon")
# Out:
# Stark is related to Winterfell, as Aerys is related to Targaryen
# Jaime is related to Kingslayer, as Lord is related to Tywin
# Dany is related to Queen, as Snow is related to Jon
# F:\Anaconda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   after removing the cwd from sys.path.
# 'Snow'
